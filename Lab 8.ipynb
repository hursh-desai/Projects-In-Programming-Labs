# %%
# !python3 webserver.py
# Out:
#  * Serving Flask app "webserver" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 241-759-948
# 208.82.101.39 - - [12/Apr/2020 20:42:36] "GET /station_status?station_id=72 HTTP/1.1" 200 -
# 208.82.101.39 - - [12/Apr/2020 20:43:18] "GET /station_status?station_id=72 HTTP/1.1" 200 -
#  * Detected change in '/home/ubuntu/notebooks/webserver.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 241-759-948
#  * Detected change in '/home/ubuntu/notebooks/webserver.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 241-759-948
# 208.82.101.39 - - [12/Apr/2020 20:48:31] "GET /station_status?station_id=82 HTTP/1.1" 500 -
# Traceback (most recent call last):
# ...

# %%
exit
